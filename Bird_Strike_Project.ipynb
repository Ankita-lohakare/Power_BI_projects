# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Bird_Strikes_Final.csv')

# %%
df.head()
# Out:
#    Record ID Aircraft: Type                Airport: Name Altitude bin  \
# 0     202152       Airplane                 LAGUARDIA NY    > 1000 ft
# 1     208159       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2     207601       Airplane            LAKEFRONT AIRPORT    < 1000 ft
# 3     215953       Airplane          SEATTLE-TACOMA INTL    < 1000 ft
# 4     219878       Airplane                 NORFOLK INTL    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
# 2                C-500                Over 100
# 3            B-737-400                Over 100
# 4         CL-RJ100/200                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight     FlightDate  \
# 0                             859         Engine Shut Down  11/23/00 0:00
# 1                             424                     None   7/25/01 0:00
# ...

# %%
df.tail()
# Out:
#        Record ID Aircraft: Type                    Airport: Name Altitude bin  \
# 25553     321151       Airplane                REDDING MUNICIPAL    > 1000 ft
# 25554     319677       Airplane                     ORLANDO INTL    < 1000 ft
# 25555     319680            NaN                              NaN          NaN
# 25556     319679       Airplane  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft
# 25557     319593       Airplane     ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft
#
#       Aircraft: Make/Model Wildlife: Number struck  \
# 25553              EMB-120                       1
# 25554                A-321                       1
# 25555               EC-135                     NaN
# 25556            B-757-200                       1
# 25557            B-737-400                       1
#
#        Wildlife: Number Struck Actual Effect: Impact to flight     FlightDate  \
# 25553                               1                     None  12/30/11 0:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25558 entries, 0 to 25557
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Record ID                                25558 non-null  int64
#  1   Aircraft: Type                           25429 non-null  object
#  2   Airport: Name                            25429 non-null  object
#  3   Altitude bin                             25429 non-null  object
#  4   Aircraft: Make/Model                     25558 non-null  object
#  5   Wildlife: Number struck                  25429 non-null  object
#  6   Wildlife: Number Struck Actual           25558 non-null  int64
#  7   Effect: Impact to flight                 25429 non-null  object
#  8   FlightDate                               25429 non-null  object
#  9   Effect: Indicated Damage                 25558 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Record ID                                     0
# Aircraft: Type                              129
# Airport: Name                               129
# Altitude bin                                129
# Aircraft: Make/Model                          0
# Wildlife: Number struck                     129
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                    129
# FlightDate                                  129
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                267
# Aircraft: Airline/Operator                  129
# Origin State                                449
# When: Phase of flight                       129
# Conditions: Precipitation                     0
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                    4771
# Wildlife: Size                              129
# Conditions: Sky                               0
# ...

# %%
df1 = df[['Airport: Name','Altitude bin','Wildlife: Number Struck Actual','Effect: Impact to flight','FlightDate',
          'Effect: Indicated Damage','Aircraft: Airline/Operator','Origin State','When: Phase of flight',
         'Wildlife: Size','Conditions: Sky','Wildlife: Species','Pilot warned of birds or wildlife?',
          'Feet above ground',]]  # Data selection

# %%
df1.head()
# Out:
#                  Airport: Name Altitude bin  Wildlife: Number Struck Actual  \
# 0                 LAGUARDIA NY    > 1000 ft                             859
# 1  DALLAS/FORT WORTH INTL ARPT    < 1000 ft                             424
# 2            LAKEFRONT AIRPORT    < 1000 ft                             261
# 3          SEATTLE-TACOMA INTL    < 1000 ft                             806
# 4                 NORFOLK INTL    < 1000 ft                             942
#
#   Effect: Impact to flight     FlightDate Effect: Indicated Damage  \
# 0         Engine Shut Down  11/23/00 0:00            Caused damage
# 1                     None   7/25/01 0:00            Caused damage
# 2                     None   9/14/01 0:00                No damage
# 3    Precautionary Landing    9/5/02 0:00                No damage
# 4                     None   6/23/03 0:00                No damage
#
#   Aircraft: Airline/Operator Origin State When: Phase of flight  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25558 entries, 0 to 25557
# Data columns (total 14 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Airport: Name                       25429 non-null  object
#  1   Altitude bin                        25429 non-null  object
#  2   Wildlife: Number Struck Actual      25558 non-null  int64
#  3   Effect: Impact to flight            25429 non-null  object
#  4   FlightDate                          25429 non-null  object
#  5   Effect: Indicated Damage            25558 non-null  object
#  6   Aircraft: Airline/Operator          25429 non-null  object
#  7   Origin State                        25109 non-null  object
#  8   When: Phase of flight               25429 non-null  object
#  9   Wildlife: Size                      25429 non-null  object
#  10  Conditions: Sky                     25558 non-null  object
# ...

# %%
df1.isnull().sum()
# Out:
# Airport: Name                         129
# Altitude bin                          129
# Wildlife: Number Struck Actual          0
# Effect: Impact to flight              129
# FlightDate                            129
# Effect: Indicated Damage                0
# Aircraft: Airline/Operator            129
# Origin State                          449
# When: Phase of flight                 129
# Wildlife: Size                        129
# Conditions: Sky                         0
# Wildlife: Species                       0
# Pilot warned of birds or wildlife?    129
# Feet above ground                     129
# dtype: int64

# %%
df1.to_csv('Bird_strike_df1.csv') # saving in csv

# %%
df2 = pd.read_csv('Bird_strike_df1.csv')

# %%
df2.head()
# Out:
#                  Airport: Name  Altitude bin(>1000)  \
# 0                 LAGUARDIA NY                  1.0
# 1  DALLAS/FORT WORTH INTL ARPT                  0.0
# 2            LAKEFRONT AIRPORT                  0.0
# 3          SEATTLE-TACOMA INTL                  0.0
# 4                 NORFOLK INTL                  0.0
#
#    Wildlife: Number Struck Actual Effect: Impact to flight  FlightDate  \
# 0                             859         Engine Shut Down  01-01-2000
# 1                             424                     None  01-01-2001
# 2                             261                     None  01-01-2001
# 3                             806    Precautionary Landing  01-01-2002
# 4                             942                     None  01-01-2003
#
#   Effect: Indicated Damage Aircraft: Airline/Operator Origin State  \
# 0            Caused damage                US AIRWAYS*     New York
# 1            Caused damage          AMERICAN AIRLINES        Texas
# ...

# %%
df2.isnull().sum()
# Out:
# Airport: Name                         129
# Altitude bin(>1000)                   129
# Wildlife: Number Struck Actual          0
# Effect: Impact to flight              129
# FlightDate                            129
# Effect: Indicated Damage                0
# Aircraft: Airline/Operator            129
# Origin State                          449
# When: Phase of flight                 129
# Wildlife: Size                        129
# Conditions: Sky                         0
# Wildlife: Species                       0
# Pilot warned of birds or wildlife?    129
# Feet above ground                     129
# dtype: int64

# %% [markdown]
# # Handling Missing Values:

# %%
df2 = df2.fillna({'Airport: Name': df2['Airport: Name'].mode()[0]})

# %%
df2 = df2.fillna({'Altitude bin(>1000)': df2['Altitude bin(>1000)'].median()})

# %%
df2 = df2.fillna({'Effect: Impact to flight': df2['Effect: Impact to flight'].mode()[0]})

# %%
df2 = df2.fillna({'FlightDate': df2['FlightDate'].mode()[0]})

# %%
df2 = df2.fillna({'Aircraft: Airline/Operator': df2['Aircraft: Airline/Operator'].mode()[0]})

# %%
df2 = df2.fillna({'Origin State': df2['Origin State'].mode()[0]})

# %%
df2 = df2.fillna({'When: Phase of flight': df2['When: Phase of flight'].mode()[0]})

# %%
df2 = df2.fillna({'Pilot warned of birds or wildlife?': df2['Pilot warned of birds or wildlife?'].mode()[0]})

# %%
df2 = df2.fillna({'Wildlife: Size': df2['Wildlife: Size'].mode()[0]})

# %%
df2 = df2.fillna({'Feet above ground': df2['Feet above ground'].mean()})

# %%
df2.isnull().sum()
# Out:
# Airport: Name                         0
# Altitude bin(>1000)                   0
# Wildlife: Number Struck Actual        0
# Effect: Impact to flight              0
# FlightDate                            0
# Effect: Indicated Damage              0
# Aircraft: Airline/Operator            0
# Origin State                          0
# When: Phase of flight                 0
# Wildlife: Size                        0
# Conditions: Sky                       0
# Wildlife: Species                     0
# Pilot warned of birds or wildlife?    0
# Feet above ground                     0
# dtype: int64

# %%
df2.to_csv('Bird_strike_df2.csv') # saving in csv
